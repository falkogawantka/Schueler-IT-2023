# %% [markdown]
# # Schüler-IT Sommersemester 2023
# ## Notebook 4: Software Engineering, Vorgehensmodelle und Werkzeuge

# %% [markdown]
# Hallo liebe Schüllerinnen und Schüler. Das ist eine Jupyternotebook, in diesem könnt ihr lernen zu programmieren. Als Quelle zum Nachlesen kann die offizielle Python Referenz verwendet werden: https://docs.python.org/3/tutorial/

# %% [markdown]
# ## 1. Software Engineering Warum?

# %% [markdown]
# ### 1. Aufgabe
# Kannst du herausfinden was Line Of Code (LOC) bedeutet?
#
# Antwort:
#
# Quelle:

# %% [markdown]
# ### 2. Aufgabe
# Kannst du herausfindne wie viel Zeilen Code eine Boing 777 300 hat
#
# Antwort:
#
# Quelle:

# %% [markdown]
# ### 3. Aufgabe
# Warum ist die Rakete Ariane 5 abgestürzt?
#
# Antwort:
#
# Quelle:

# %% [markdown]
# ### 4. Aufgabe
# Recherchiere im Netz nach jeweils drei Vorteilen und drei Nachteilen des Wasserfallmodells! Liste die Vorteile sowie die Quellen auf.
#
# Vorteile und (Quellen):
# Beispiel 1. sehr schnell (nullwissen.de)
#
# Nachteile und (Quellen):

# %% [markdown]
# ### 5. Aufgabe
# Liste alle Rollen des Scrum Vorgehensmodells auf die du finden kannst. Denke an die Angabe der Quellen! Ein erstes Beispiel findest du unten.
#
# Rollen:
# 1. Product-Owner - Kunde (https://scrumguide.de/scrum-rollen/)

# %% [markdown]
# ## 2. Werkzeuge/Aufgaben für die Software Entwicklung

# %% [markdown]
# ### Beschreibung des Szenarios - Projektmanager
#
# Du bist Projektmanager bei AY Technology und triffst dich mit einem potentiellen Kunden. Er beschreibt, dass er folgendes Produkt entwickelt haben möchte.
#
# Hr. Ungeduldig will ein Webshop für Hundepflege Artikel umgesetzt haben. In diesem Webshop sollen sich Nutzer anmelden können und man soll die Angebote der Website in einen Warenkorb legen. Das soll alles ganz ähnlich wie bei Amazon oder in anderen Webshops funktionieren. Das besondere ist, dass nach jedem 10 Einkauf das dritte Produkt im Warenkorb nicht berechnet wird.
#
# Du sollst als Projektmanager die Anforderungen festhalten.

# %% [markdown]
# ### 1. Aufgabe
# Du sollst ein Dokument erstellen welches die Wünsche von Herrn Ungeduldig festhält. Für welches Programm würdest du dich entscheiden begründe deine Wahl.
#
# Antwort:
#
# Begründung:

# %% [markdown]
# ### 2. Aufgabe
# Liste die Stichpunkte von Herrn Ungeduldig auf. Achte darauf das du keine Details vergisst.
#
# Liste:
# - abcd

# %% [markdown]
# ### 3. Aufgabe
#
# Nachdem du ein Anforderungsdokument erstellt hast, möchtest du eine E-Mail an deine Entwicklungsleiterin schreiben.
#
# E-Mail:
#
# Sehr geehrte Frau Schnell,
#
# eine neuer Kunde möchte einen Webshop von uns haben. Dieser soll folgende Eigenschaften besitzen:
#
# Liste von Punkten
# …
#
# Können Sie bitte schauen, ob Sie einen ähnlichen Anwendungsfall haben und auf ein bestehendes Muster für einen Webshop zurückgreifen können. Der Kunde möchte den Auftrag in den nächsten 45 Tagen umgesetzt haben. Können Sie bitte eine Ressourcenplanung durchführen!

# %% [markdown]
# ### Beschreibung des Szenarios - Entwicklungsleiterin
#
# Die E-Mail erreicht dich Montag 16.30 Uhr. Was machst du?
#
# 1. Feierabend!
# 2. Du liest sie und machst dir für morgen eine Notiz.
# 3. Du siehst sofortigen handlungsbedarf!
#
# Antwort:
#
# _______________
# Tag 2
# Du kommst Dienstag Morgen in das Büro und siehst dir den Dienstplan deiner Entwickler an. Die Zahl in Klammern legen die Prioritäten der Aufgaben fest.
#
# |Namen|Tom | Lisa | Marlon| Marit
# |--|--|--|--|--
# |Vormittag|Betreuung Praktikant (3)   | Projekt Siemens (2) | Projekt FhG IOSB-AST (2) | KIA (1)
# |Nachmittag|Schulung Admins (1)| Projekt Siemens (2) | Projekt Siemens (1) | --

# %% [markdown]
# ### 1. Aufgabe
#
# Benachrichtige den Entwickler dem du noch ein Meeting aufdrücken kannst. Und gehe mit ihm/ihr die Mail mit den Punkten des Managers durch.

# %% [markdown]
# ### Beschreibung des Szenarios - Software-Architektin/Software-Entwicklerin
#
# Du (Mitarbeiterin Marit) bekommst eine Benachrichtigung über ein Meeting heute Nachmittag. Du weißt das es um einen Webshop geht. Du wurdet im Unternehmen schon als Architektin und Entwicklerin in großen und schwierigen Projekten eingesetzt.
#
# Tatsächlich findest du im Projekt-Repository einen alten Entwurf den du nutzen könntest. Du nimmst ihn mit zu der Besprechung.
#
# ![einkauf_beginn.svg](attachment:einkauf_beginn.svg)

# %% [markdown]
# ### 1. Aufgabe
#
# Du willst das Digramm gleich noch etwas vervollständigen und erweiterst das bestehende draw.io Diagramm. Es befindet sich in der Firmen-Cloud: https://drive.google.com/drive/folders/1nA9EYW8F2FoxCGgrK66-4iqcbVdLzU7s?usp=sharing .
#
# Du sollst das Diagramm in draw.io öffnen.

# %% [markdown]
# ### 2. Aufgabe
#
# Füge dem Web-Shop Modul folgende Komponenten hinzu:
#
# 1. Web-Ansicht
# 2. Warenkorb
# 3. Wunschliste
# 4. Informationen über Bestellungen
# 5. Ändern der Nutzer Informationen
#
# Diese Sollen einfach als kleinere Rechtecke in das Web-Shop Modul integriert werden.

# %% [markdown]
# ### 3. Aufgabe
#
# Überlege dir anhand des obigen Beispiels, welches Modul im Bezug auf den Nutzer vergessen wurde. Hilfe: "Kann man seine Daten ohne ein Benutzerkonto ändern?"
#
# vergessene Module:
# 1. ...

# %% [markdown]
# ### 4. Aufgabe
#
# Die Nutzerverwaltung ist ein System, welches aus folgenden Subsystemen besteht:
#
# - User-Subsystem
# - Order-Subsystem
# - Shopping-Cart-Subsystem
# - Wishlist-Subsystem
#
# Füge Sie der Nutzerverwaltung hinzu.

# %% [markdown]
# ### 5. Aufgabe
#
# Beginne mit der Definition des Einkaufswagens (Shaoping-Cart) vielleicht solltest du einheitliche Namen einführen.

# %% [markdown]
# ### 6. Aufgabe
#
# Überlege dir was ein Warenkorb in dem Web-Shop für **Funktionen** benötigt, halte dich an die vorgestellten Konventionen. Die Konvention zur Definition von Funktionen war:
#
# - abgerundete Rechtwecke mit dem Funktionsnamen benutzen
# - die Werden in das jeweilige Submodul integriert

# %% [markdown]
# ### 7. Aufgabe
#
# Füge das Ergebnis deines Entwurfes hier ein!
#
# 1. Exportiere deinen Entwurf als **.SVG** Datei.
# 2. Klicke oben in der Menüleiste auf **Edit** und wähle **Insert Image** aus.
# 3. Gehe im Dialog Fenster auf **Datei auswählen** und nimm die Datei von deinem Computer.
#
#
# Ergebnis:
#
# - Bild hier einfügen bitte!!!

# %% [markdown]
# ### Beschreibung des Szenarios - Software-Entwickler
#
# Du bist jetzt in der Rolle eines sehr guten Praktikanten. Marit sendet dir das folgende Diagramm und du sollst es entsprechend umsetzen.

# %% [markdown]
# ### 1. Aufgabe
#
# Du sollst das Modul des Warenkorbs in Python implementieren. Mache dir als Erstes Gedanken wie ein Eintrag des Warenkorbs aussehen soll. Du weißt das folgende Informationen gespeichert werden müssen:
#
# 1. Name des Produktes
# 2. Artikelnummer
# 3. Preis
# 4. Verfügbarkeit

# %% [markdown]
# ### 2. Aufgabe
#
# Welche der bisherigen Strukturen kommen infrage wenn du mehrere Informationen zu einer Sache speichern möchtest?
#
# Auswahl:
#
# 1. Variable (Zahl, String etc.)
# 2. Liste
#
# Deine Wahl:
#
# Begründung:

# %% [markdown]
# ### 3. Aufgabe
#
# Nach der Wahl einer Datenstruktur sollst du drei Beispiele für Warenkorbeinträge definieren.

# %%
##
# Beispiele für Warenkorbeinträge
##
example_ = ['Hunde-Deo', 123456, 12.45, True]

# %% [markdown]
# ### 4. Aufgabe
#
# Mache dir Gedanken über den Warenkorb. Was für eine Datenstruktur würdest du für ihn verwenden. Hinweis es werden mehrere Produkte im Warenkorb gespeichert. Und es müssen auch wieder Produkte entfernt werden können.
#
# Wahl der Datenstruktur:
#
# Begründung:

# %% [markdown]
# ### 5. Aufgabe
#
# Schreibe zwei Funktionen für den Warenkorb:
# 1. Eine Funktion, welche ein Produkt zu Warenkorb hinzufügt. Nenne sie **add_to_shopping_cart()**.
# 2. eine Funktion, die ein Element entfernen kann. Nenne sie **remove_from_shopping_cart_by_id()**.

# %%
class shopping_cart:
    def __init__(self):
        self.shopping_cart_ = []
    
    def add_to_shopping_cart(self, shopping_cart_item: list):
        self.shopping_cart_.append(shopping_cart_item)
    
    def remove_from_shopping_cart_by_id(self, product_id: int):
        ##
        # just test code: todo
        ##
        return 0
    
    def print_shopping_cart(self):
        print(self.shopping_cart_)

# %%
##
# test code
##

cart = shopping_cart()
cart.print_shopping_cart()
# Out:
# []

# %%
cart.add_to_shopping_cart(['Hunde-Deo', 123456, 12.45, True])

# %%
cart.print_shopping_cart()
# Out:
# [['Hunde-Deo', 123456, 12.45, True]]
