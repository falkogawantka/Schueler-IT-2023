# %% [markdown]
# # Schüler-IT Sommersemester 2023
# ## Notebook 4: Software Engineering, Vorgehensmodelle und Werkzeuge

# %% [markdown]
# Hallo liebe Schüllerinnen und Schüler. Das ist eine Jupyternotebook, in diesem könnt ihr lernen zu programmieren. Als Quelle zum Nachlesen kann die offizielle Python Referenz verwendet werden: https://docs.python.org/3/tutorial/

# %% [markdown]
# # 1. Teil: Wiederholung wichtiger Inhalte

# %% [markdown]
# ### 1. Aufgabe
#
# Frage: Wie heißt die Funktion, die eine Zeichenkette auf der Konsole ausgeben kann?
#
# Antwort: abc

# %% [markdown]
# ### 2. Aufgabe
#
# Rufe die Funktion aus Aufgabe 1 auf und lass deinen Namen auf der Konsole anzeigen.
#
# Bedingung: Übergebe deinen Namen in einer Variable.

# %%
##
# Aufgabe 2: schreibt euren Code bitte unter diesen Kommentar
##

# %% [markdown]
# ### 3. Aufgabe
#
# Schreibe eine Funktion die, die aktuelle Uhrzeit auf der Konsole anzeigt. Eine mögliche Bibliothek zum anzeigen der Zeit findest du hier: https://www.ionos.de/digitalguide/websites/web-entwicklung/python-datetime/#:~:text=Falls%20Sie%20auch%20die%20aktuelle,das%20auf%20die%20Millisekunde%20genau.

# %%
##
# Aufgabe 3: schreibt euren Code bitte unter diesen Kommentar
##

# %% [markdown]
# ### 4. Aufgabe
#
# Frage: Was ist eine Software-Bibliothek?
#
# Antwort: abc
#
# Quelle:

# %% [markdown]
# ### 5. Aufgabe
#
# Liste bitte mindestens 3 von dir genutzte Software Bibliotheken auf und beschreibe kurz wozu diese gut sind.
#
# - Beispiel 1:
# - genutzt für:
#
# - Beispiel 2:
# - genutzt für:
#
# - Beispiel 3:
# - genutzt für:

# %% [markdown]
# # 2. Teil: Grafikfunktionen mit dem Raspberry Pi und dem OLED Display

# %% [markdown]
# ### 1. Aufgabe:
#
# Beschreibe die Schritte die notwendig sind um einen neuen Inhalt auf dem kleinen OLED Panel anzuzeigen.
#
# Hinweis: Drei wesenstliche Schritte sind notwendig!
#
# Antwort:
# - a
# - b
# - c

# %% [markdown]
# Hilfestellung
#
# ![graphic_loop.png](attachment:graphic_loop.png)

# %% [markdown]
# ### 2. Aufgabe
#
# Bschreibe die drei Funktionen aus dem ersten Block oben, wie folgt.
#
# - Funktion: fill() -> Name der Funktion die den Dsiplay Puffer auf einen gegbenen Wert setzt.
# - 1. Argument: 0 -> Der Wert der in den Display Puffer geschrieben wird.
#
# Bitte ergänze folgende Funktionen:
#
# - Funktion: text()
# - 1. Argument:
# - 2. Argument:
# - 3. Argument:
# - 4. Argument:
# - 5. Argument:
#
# - Funktion: show()
# - keine Argumente

# %% [markdown]
# ### 3. Aufgabe
#
# Frage: Welches Übertragungsprotokoll wurde genutzt um das Display anzusteuern?
#
# Antwort: abc

# %% [markdown]
# ### 4. Aufgabe
#
# Frage: Wozu dienen Protokolle?
#
# Antwort: abc

# %% [markdown]
# ### 5. Aufgabe
#
# Frage: Nenne zwei Protokolle die im Internet eingesetzt werden, um Daten zu übertragen.
#
# 1. abc
# 2. def

# %% [markdown]
# # 3. Teil: Grafikprogrammierung
#
# In den Präsentationen ging es mehrfach darum was Rasterung ist. Erkläre folgende Begriffe mit deinen, eigenen Worten

# %% [markdown]
# ### 1. Aufgabe
#
# Erkläre den Begriff: "Raster"
#
# Antwort: abc

# %% [markdown]
# ### 2. Aufgabe
#
# Erkläre den Begriff: "Rasterung" und beschreibe was bei der Rasterung einer Linie passiert.
#
# Antwort: abc

# %% [markdown]
# ### 3. Aufgabe
#
# Sieh dir den folgenden Pseudo-Code an:
#
# The steps involved in DDA line generation algorithm are:
#
# 1. Input the two endpoints of the line segment, (x1,y1) and (x2,y2).
# 2. Calculate the difference between the x-coordinates and y-coordinates of the endpoints as dx and dy respectively.
# 3. Calculate the slope of the line as m = dy/dx.
# 4. Set the initial point of the line as (x1,y1).
# 5. Loop through the x-coordinates of the line, incrementing by one each time, and calculate the corresponding y-coordinate using the equation y = y1 + m(x – x1).
# 6. Plot the pixel at the calculated (x,y) coordinate.
# 7. Repeat steps 5 and 6 until the endpoint (x2,y2) is reached.
#
# Wenn du nicht weißt was Pseudo-Code ist kannst du hier nachlesen, was das ist: https://www.computerweekly.com/de/definition/Pseudocode#:~:text=Pseudocode%20ist%20eine%20detaillierte%20und,nicht%20in%20einer%20Programmiersprache%20ausgedr%C3%BCckt.

# %% [markdown]
# ### 4. Aufgabe
#
# Falls die Implementierung anhand von Pseudocode zu schwierig ist, beginne hier. Als erstes benötigen wir eine Bibliothek zum Erstellen von Grafiken und Ähnlichem. Hierfür kann man matplotlib https://matplotlib.org/stable/tutorials/introductory/quick_start.html#sphx-glr-tutorials-introductory-quick-start-py nutzen.
#
# Desweiteren wollen wir den DDA Algorithmus für die Rasterung einer Linie verwenden https://www.javatpoint.com/computer-graphics-dda-algorithm. Weitere
# Quellen:
# - https://iq.opengenus.org/dda-digital-differential-analyzer-line-drawing-algorithm/
# - https://web.cse.ohio-state.edu/~shen.94/681/Site/DDA.html

# %%
##
# Schritt 1: Laden der Bibliothek in die Umgebung des Notebooks
##

from matplotlib import pyplot as plt

# %% [markdown]
# ### 5. Aufgabe
#
# Du musst als erstes die Funktion ''DDA'' definieren, diese soll vier Argumente bekommen. Die vier Argumente stehen für die Koordinaten Werte des Start und Endpunktes der Geraden. Einen Teil der Funktion ist gegeben, ein Kollege hat schon mit der Umsetzung begonnen. Leider ist er krank geworden und nun musst du das Projektabschließen.
#
# Hinweis: nutze den Pseudo Code um die fehlenden Teile der Funktion zu ergänzen.

# %%
##
# Schritt 2: definieren der Funktion
##

def DDA(x0, y0):
    dx = abs(x0 - x1)
 
    steps = max(dx, dy)
 
    xinc = dx/steps
 
    y = float(y0)
 
    y_coorinates = []
 
    for i in range(steps):
        x_coorinates.append(x)
 
        x = x + xinc
        y = y + yinc
 
    plt.plot(x_coorinates, y_coorinates, marker="o",
             markersize=1, markerfacecolor="green")
    plt.show()

# %% [markdown]
# ### 6. Aufgabe
#
# Die gute Nachricht ist, der Programmcode zum Testen funktioniert schon, du musst nur die Funktion implementieren.

# %%
x0, y0 = 20, 20
x1, y1 = 12, 23
 
# Function call
DDA(x0, y0, x1, y1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-90449ce441dd> in <module>
#       3
#       4 # Function call
# ----> 5 DDA(x0, y0, x1, y1)
#
# TypeError: DDA() takes 2 positional arguments but 4 were given

# %% [markdown]
# # Viel Erfolg bei der Bearbeitung der Aufgaben
